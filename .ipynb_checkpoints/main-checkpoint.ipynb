# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
survey = pd.read_csv("survey_results_public.csv")

# %%
survey
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
survey.Age
# Out:
# 0           18-24 years old
# 1           25-34 years old
# 2           45-54 years old
# 3           25-34 years old
# 4           25-34 years old
#                 ...
# 89179       25-34 years old
# 89180       18-24 years old
# 89181     Prefer not to say
# 89182    Under 18 years old
# 89183       35-44 years old
# Name: Age, Length: 89184, dtype: object

# %%
survey.set_index("ResponseId", inplace=True)

# %%
survey
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
survey.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %%
age_language_filter = (survey["Age"] == "18-24 years old") & (survey["LanguageHaveWorkedWith"].str.contains("Assembly" , na=False))

# %%
survey[age_language_filter]
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 19          I agree                     I am a developer by profession
# 82          I agree                        I code primarily as a hobby
# 86          I agree                     I am a developer by profession
# 91          I agree                     I am a developer by profession
# 169         I agree  I used to be a developer by profession, but no...
# ...             ...                                                ...
# 89145       I agree                     I am a developer by profession
# 89152       I agree  I am not primarily a developer, but I write co...
# 89167       I agree                     I am a developer by profession
# 89169       I agree                     I am a developer by profession
# 89182       I agree                        I code primarily as a hobby
#
#                         Age  \
# ResponseId
# 19          18-24 years old
# 82          18-24 years old
# ...

# %%
sorted_survey = survey.sort_values(by=['ConvertedCompYearly', 'YearsCode'], ascending=[False, True])
sorted_survey
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 53269       I agree  I am a developer by profession  18-24 years old
# 77849       I agree  I am a developer by profession  18-24 years old
# 66224       I agree  I am a developer by profession  18-24 years old
# 28122       I agree  I am a developer by profession  18-24 years old
# 19680       I agree  I am a developer by profession  18-24 years old
# ...             ...                             ...              ...
# 88884       I agree  I am a developer by profession  18-24 years old
# 88941       I agree           I am learning to code  18-24 years old
# 89029       I agree                   None of these  18-24 years old
# 89135       I agree     I code primarily as a hobby  18-24 years old
# 89160       I agree                   None of these  18-24 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
sorted_survey["ConvertedCompYearly"].mean()
# Out:
# 103110.08171765343

# %%
plt.style.use('_mpl-gallery')
# print()
# # print(survey[age_language_filter]["ConvertedCompYearly"].value_counts)
# # print(survey[age_language_filter].loc[:,'ConvertedCompYearly'])
# survey[age_language_filter]["ConvertedCompYearly"].max()
#make data:
# x = 0.5 + np.arange(len(survey[age_language_filter]))
# y = survey[age_language_filter]["ConvertedCompYearly"].values


# # plot
# fig, ax = plt.subplots()

# ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

# ax.set(xlim=(0, 8), xticks=np.arange(survey[age_language_filter].index),
#        ylim=(0, 8), yticks=np.arange(1, survey[age_language_filter]["ConvertedCompYearly"].max()))

###########################
x = 0.5 + np.arange(5)
y = [5,2,10,3,9]


# plot
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white", linewidth=1,)

ax.set(xlim=(0, 8), xticks=np.arange(1,10),
       ylim=(0, 8), yticks=np.arange(1, 10))


plt.show()
